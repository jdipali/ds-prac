# %%
list1 = []
print("Enter 5 numbers: ")
for i in range(0, 5):
    v = input()
    list1.append(v)
    list2 = []
print("Enter 5 numbers: ")
for i in range(0, 5):
    v = input()
    list2.append(v)
    flag = []
for i in list1:
    if i in list2:
        flag = 1
    if(flag == 1):
        print("Lists Overlap")
    else:
        print("Lists don't Overlap")
# Out:
# Enter 5 numbers:
#  1
#  2
#  3
#  4
#  5
# Enter 5 numbers:
#  6
#  7
#  8
#  9
#  0
# Lists don't Overlap
# Lists don't Overlap
# Lists don't Overlap
# Lists don't Overlap
# Lists don't Overlap

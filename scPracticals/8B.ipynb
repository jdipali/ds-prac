# %%
x = 5
if(type(x) is not int):
    print('True')
else:
    print('False')
# Out:
# False

# %%
x = 5
if(type(x) is int):
    print('True')
else:
    print('False')
# Out:
# True

# %%
x = int(input('Enter value of x: '))
if(type(x) is int):
    print('True')
else:
    print('False')
# Out:
# Enter value of x:  0.01
# False

# %%
x = int(input('Enter value of x: '))
if(type(x) is int):
    print('True')
else:
    print('False')
# Out:
# Enter value of x:  1
# False
